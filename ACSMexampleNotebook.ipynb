# %% [markdown]
# ## Imports

# %%
import sys
#change this path to the location of your local GitHub repository
sys.path.append('C:\\Users\\peo0005\\OneDrive - Auburn University\\Documents\\GitHub\\acsm')

import matplotlib.pyplot as plt
import pandas as pd
from acsmdata import ACSMdata
import numpy as np

# %% [markdown]
# ### Location of datafile

# %%
#path to folder with data in it
path = "C:\\Users\\peo0005\\OneDrive - Auburn University\\Documents\\GitHub\\acsm\\exampleData\\"

#name of datafile
name = "massspec_240729.csv"

fullpath = path + name

# %% [markdown]
# ## Import the data into the 'data' object

# %%
data = ACSMdata(fullpath)
# Out:
# Imported DataFrame.
#
# Rows dropped because of NaN:
# 323   2024-07-29 19:24:00
# 324   2024-07-29 19:24:00
# 325   2024-07-29 19:25:00
# 326   2024-07-29 19:26:00
# 328   2024-07-29 19:27:00
# 330   2024-07-29 19:28:00
# 331   2024-07-29 19:29:00
# 333   2024-07-29 19:30:00
# 334   2024-07-29 19:31:00
# 336   2024-07-29 19:32:00
# 337   2024-07-29 19:33:00
# 338   2024-07-29 19:34:00
# 339   2024-07-29 19:34:00
# 340   2024-07-29 19:35:00
# 341   2024-07-29 19:36:00
# 342   2024-07-29 19:36:00
# 343   2024-07-29 19:37:00
# 344   2024-07-29 19:38:00
# 345   2024-07-29 19:38:00
# 346   2024-07-29 19:39:00
# 347   2024-07-29 19:40:00
# 349   2024-07-29 19:41:00
# 350   2024-07-29 19:42:00
# 351   2024-07-29 19:42:00
# 352   2024-07-29 19:43:00
# 354   2024-07-29 19:44:00
# 355   2024-07-29 19:45:00
# 356   2024-07-29 19:46:00
# 358   2024-07-29 19:47:00
# 359   2024-07-29 19:48:00
# 360   2024-07-29 19:48:00
# 361   2024-07-29 19:49:00
# Name: time_index, dtype: datetime64[ns]

# %% [markdown]
# ## Call function on the data object to print and other things:

# %%
data.printDF()
# Out:
#              time_index      'm/Q 4'      'm/Q 5'   'm/Q 6'      'm/Q 7'  \
# 0   2024-07-29 15:48:00    -0.029974    -0.035713  0.020615     0.009525
# 1   2024-07-29 15:49:00    -0.010494    -0.001578  0.001301     0.002282
# 2   2024-07-29 15:49:00    -0.039237    -0.006321  0.021813    -0.005366
# 3   2024-07-29 15:50:00     0.009368    -0.006841 -0.009519    -0.006872
# 4   2024-07-29 15:51:00    -0.022385    -0.008952  0.005217    -0.003723
# ..                  ...          ...          ...       ...          ...
# 327 2024-07-29 19:40:00  3800.770000     0.000000  0.000000     0.000000
# 328 2024-07-29 19:44:00     0.000000     0.000000  0.000000     0.000000
# 329 2024-07-29 19:46:00     0.000000  6651.210000  0.000000  2748.190000
# 330 2024-07-29 19:50:00     0.099711     0.120290  0.087352     0.080060
# 331 2024-07-29 19:50:00    -0.009579     0.006789 -0.002764    -0.010545
#
#       'm/Q 8'      'm/Q 9'     'm/Q 10'     'm/Q 11'  'm/Q 12'  ...  \
# ...

# %% [markdown]
# ## Plot an average MZ spectrum:

# %%
#time bounds calculate for certain period of time
start = "2024-07-29 16:30:00"
end = "2024-07-29 17:00:00"

#tlim, mzlim, and ylim are all optional parameters
data.plotAveSpectrum(tlim = [start,end], mzlim=[0,100], ylim = [-2,40])

# %% [markdown]
# ## Plot an individual MZ over time:

# %%
#time bounds calculate for certain period of time
start = "2024-07-29 14:30:00"
end = "2024-07-29 17:00:00"

#tlim and ylim are optional imputs
data.plotIndMZ(43,tlim = [start,end], ylim=[-0.5,5])

# %%
#time bounds calculate for certain period of time
start = "2024-07-29 15:30:00"
end = "2024-07-29 17:00:00"

data.plotTotalMass(tlim = [start,end])
