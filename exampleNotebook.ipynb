# %%
import matplotlib.pyplot as plt
import pandas as pd
from acsmdata import ACSMdata

# %%
#path to folder with data in it
path = "C:\\Users\\peo0005\\OneDrive - Auburn University\\Documents\\GitHub\\acsm\\exampleData\\"

#name of datafile
name = "massspec_240729.csv"

fullpath = path + name

# %%
data = ACSMdata(fullpath)

# %%
data.printDF()
# Out:
#              time_index   'm/Q 4'   'm/Q 5'   'm/Q 6'   'm/Q 7'   'm/Q 8'  \
# 0   2024-07-29 15:48:00 -0.029974 -0.035713  0.020615  0.009525 -0.006166
# 1   2024-07-29 15:49:00 -0.010494 -0.001578  0.001301  0.002282 -0.027647
# 2   2024-07-29 15:49:00 -0.039237 -0.006321  0.021813 -0.005366  0.009687
# 3   2024-07-29 15:50:00  0.009368 -0.006841 -0.009519 -0.006872  0.031686
# 4   2024-07-29 15:51:00 -0.022385 -0.008952  0.005217 -0.003723  0.011725
# ..                  ...       ...       ...       ...       ...       ...
# 359 2024-07-29 19:48:00       NaN       inf       inf       NaN       NaN
# 360 2024-07-29 19:48:00       NaN       NaN       NaN       NaN       NaN
# 361 2024-07-29 19:49:00       NaN       NaN       NaN       NaN       inf
# 362 2024-07-29 19:50:00  0.099711  0.120290  0.087352  0.080060  0.063557
# 363 2024-07-29 19:50:00 -0.009579  0.006789 -0.002764 -0.010545 -0.032448
#
#       'm/Q 9'  'm/Q 10'  'm/Q 11'  'm/Q 12'  ...  'm/Q 232'  'm/Q 233'  \
# 0   -0.009168 -0.010986 -0.003977 -0.099243  ...   0.002819  -0.003706
# 1    0.004199 -0.000977 -0.013621  0.014453  ...  -0.000324   0.000154
# 2   -0.004529 -0.004561 -0.006746 -0.078961  ...   0.000572  -0.001302
# 3    0.004269  0.004180  0.006472 -0.020034  ...   0.000288   0.000498
# 4    0.023458  0.004448  0.004694 -0.077881  ...  -0.000051   0.001622
# ..        ...       ...       ...       ...  ...        ...        ...
# 359       NaN       NaN       inf       NaN  ...        NaN        NaN
# 360       NaN       NaN       NaN       NaN  ...        NaN        NaN
# 361       inf       NaN       NaN       NaN  ...        NaN        NaN
# 362  0.048886  0.041207  0.022478  0.292519  ...   0.002258   0.003200
# 363 -0.001828 -0.008016 -0.023152 -0.055295  ...   0.000187   0.000058
#
#      'm/Q 234'  'm/Q 235'  'm/Q 236'  'm/Q 237'  'm/Q 238'  'm/Q 239'  \
# 0     0.001070  -0.000278   0.001286  -0.001275  -0.002293  -0.001669
# 1     0.001186   0.000325   0.001670   0.001014  -0.000570  -0.001441
# 2     0.001219  -0.002670   0.000130  -0.000214  -0.000959  -0.001720
# 3    -0.002241  -0.001241  -0.000292   0.001417   0.001577  -0.000766
# 4    -0.000745   0.000058  -0.000399  -0.001341  -0.001488   0.001468
# ..         ...        ...        ...        ...        ...        ...
# 359        NaN        NaN        NaN        NaN        NaN        NaN
# 360        NaN        NaN        NaN        NaN        NaN        NaN
# 361        NaN        NaN        NaN        NaN        inf        NaN
# 362   0.002642   0.004599   0.002549   0.003726   0.001190   0.000652
# 363  -0.001390  -0.002414  -0.000930   0.000605   0.000606  -0.002232
#
#      'm/Q 240'  'm/Q 241'
# 0    -0.002215  -0.000164
# 1     0.001161  -0.000750
# 2     0.000624  -0.001237
# 3     0.001765   0.001168
# 4    -0.000973   0.001174
# ..         ...        ...
# 359        NaN        NaN
# 360        NaN        NaN
# 361        NaN        NaN
# 362   0.002736   0.000736
# 363  -0.001401  -0.000698
#
# [364 rows x 239 columns]

# %%
data.plotMZ(44,[0,1])
